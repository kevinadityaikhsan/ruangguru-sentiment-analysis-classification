# %% [markdown]
# # **Data Scraping: ruangguru's Clash of Champions YouTube Comments**
# - Dataset:  YouTube comments extracted from [ruangguru's Clash of Champions](https://www.youtube.com/@Ruangguru) episodes 1-3.
# - Date of Collection: Tueday July 29, 2024 (9:26 AM)
# - Tool: youtube_comment_downloader from [egbertbouman's GitHub](https://github.com/egbertbouman)

# %%
# !pip install youtube-comment-downloader

# %%
from youtube_comment_downloader import *

# %%
downloader = YoutubeCommentDownloader()

# %% [markdown]
# # Episode 1

# %%
comments = downloader.get_comments_from_url("https://www.youtube.com/watch?v=dY_3acmFFRQ")

comments_list = []

for comment in comments:
  comments_list.append(comment['text'])

# %% [markdown]
# # Episode 2

# %%
comments = downloader.get_comments_from_url("https://www.youtube.com/watch?v=n2sggHMSAro")

for comment in comments:
  comments_list.append(comment['text'])

# %% [markdown]
# # Episode 3

# %%
comments = downloader.get_comments_from_url("https://www.youtube.com/watch?v=IFG-F5HJDpg")

for comment in comments:
  comments_list.append(comment['text'])

# %%
import csv

# Save to CSV
with open('ruangguru_eps1-3.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['comment'])
    for comment in comments_list:
        writer.writerow([comment])

# %%
import pandas as pd

df = pd.read_csv('ruangguru_eps1-3.csv')
df
# Out:
#                                                  comment
# 0      Yuk, konsultasi dan klaim diskonnya sekarang d...
# 1           Serem njirr kalo liat orang pinter kompetisi
# 2               Kami sih sama ada kayak caslh of campion
# 3                                     Waahh merinding gw
# 4                         Siapa dari sd imam asy fi\n\n👇
# ...                                                  ...
# 42808                                             Samaa😂
# 42809                                  ternyata belum ya
# 42810  lah pantes tadi sore udah nonton , terus ilang...
# 42811                                        UDAAAA WEEE
# 42812   @ahmadmualim8537  mungkin tadi sore lupa belu...
#
# [42813 rows x 1 columns]
